# %% [markdown]
# PARTE 2 - PROBLEMA DE CLASIFICACION LINEA

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 1. IMPLEMENTAR EL PERCEPTRON SIMPLE DEL PROBLEMA VISTO EN CLASE USANDO SKLEARN

# %%
X, y = datasets.make_blobs(
    n_samples=150,
    n_features=2,
    centers=2,
    cluster_std=2.05,
    random_state=2
)

# %%
scaler = StandardScaler()
Xs = scaler.fit_transform(X)

# %%
perceptron = Perceptron( warm_start=True, random_state=42)
perceptron.fit(X, y)
# Out:
# Perceptron(random_state=42, warm_start=True)

# %% [markdown]
# 2. REPORTE LOS PESOS W, EL BIAS Y EL LOS COSTOS

# %%
epochs = 300   
costos = []
pesos = []
biases = []
accuracies = []

for epoch in range(1, epochs + 1):
        perceptron.fit(X, y)
        y_pred = perceptron.predict(X)
        

        errores = np.sum(y_pred != y)
        costo = errores
        costos.append(costo)
        acc = accuracy_score(y, y_pred)
        accuracies.append(acc)

        
        # Guardar pesos y bias
        pesos.append(perceptron.coef_[0].copy())
        biases.append(perceptron.intercept_[0])
        # Convertir proporciones a número de errores enteros



        
        print(f"Época {epoch:2d} | W: {perceptron.coef_[0]} | b: {perceptron.intercept_[0]} | Costo: {costo:.4f}")
# Out:
# Época  1 | W: [3.79879434 6.40805316] | b: 48.0 | Costo: 11.0000
# Época  2 | W: [ 5.84769782 13.50644771] | b: 53.0 | Costo: 3.0000
# Época  3 | W: [4.39233614 7.0615348 ] | b: 57.0 | Costo: 14.0000
# Época  4 | W: [ 3.97990007 11.16982624] | b: 61.0 | Costo: 3.0000
# Época  5 | W: [ 7.11308009 15.77643704] | b: 65.0 | Costo: 2.0000
# Época  6 | W: [ 5.54576771 15.99237313] | b: 66.0 | Costo: 2.0000
# Época  7 | W: [ 5.11313315 16.79273689] | b: 67.0 | Costo: 4.0000
# Época  8 | W: [ 6.16278931 11.29552683] | b: 71.0 | Costo: 6.0000
# Época  9 | W: [ 2.74441789 16.98571373] | b: 73.0 | Costo: 3.0000
# Época 10 | W: [-1.70499698 15.43389224] | b: 75.0 | Costo: 6.0000
# Época 11 | W: [ 6.45283449 16.36107031] | b: 77.0 | Costo: 1.0000
# Época 12 | W: [ 5.08635813 18.17658746] | b: 78.0 | Costo: 2.0000
# Época 13 | W: [ 6.63124267 16.25738161] | b: 78.0 | Costo: 1.0000
# Época 14 | W: [ 7.69608155 14.83302477] | b: 80.0 | Costo: 4.0000
# Época 15 | W: [ 7.21586405 13.27951561] | b: 81.0 | Costo: 5.0000
# Época 16 | W: [ 4.43134861 18.99237405] | b: 82.0 | Costo: 3.0000
# Época 17 | W: [ 4.57246672 18.1270733 ] | b: 83.0 | Costo: 1.0000
# Época 18 | W: [ 6.43264353 20.93424031] | b: 82.0 | Costo: 5.0000
# Época 19 | W: [ 6.70064989 17.27597935] | b: 83.0 | Costo: 1.0000
# Época 20 | W: [ 3.31562611 17.58727781] | b: 85.0 | Costo: 3.0000
# Época 21 | W: [ 3.81815165 18.92363536] | b: 85.0 | Costo: 2.0000
# Época 22 | W: [ 5.89079659 19.73352196] | b: 85.0 | Costo: 2.0000
# Época 23 | W: [ 3.44063461 18.20146943] | b: 85.0 | Costo: 2.0000
# Época 24 | W: [ 8.18700324 17.77794066] | b: 85.0 | Costo: 1.0000
# Época 25 | W: [ 4.87428005 18.87985881] | b: 85.0 | Costo: 1.0000
# Época 26 | W: [ 7.9153191  17.60918923] | b: 85.0 | Costo: 1.0000
# Época 27 | W: [ 2.78088823 18.60129283] | b: 85.0 | Costo: 3.0000
# Época 28 | W: [ 6.90222336 19.74162905] | b: 84.0 | Costo: 2.0000
# Época 29 | W: [ 6.66759139 17.4388089 ] | b: 84.0 | Costo: 1.0000
# Época 30 | W: [ 5.59416924 19.00568489] | b: 85.0 | Costo: 1.0000
# Época 31 | W: [ 3.69026466 17.23489501] | b: 85.0 | Costo: 3.0000
# Época 32 | W: [ 3.78597224 18.90784783] | b: 85.0 | Costo: 2.0000
# Época 33 | W: [-0.80892683 20.87004605] | b: 86.0 | Costo: 6.0000
# Época 34 | W: [ 1.49560183 18.56584993] | b: 86.0 | Costo: 3.0000
# Época 35 | W: [ 6.23939356 16.02132714] | b: 87.0 | Costo: 4.0000
# Época 36 | W: [ 6.81035294 17.30275461] | b: 87.0 | Costo: 3.0000
# Época 37 | W: [ 7.2763593  13.78586923] | b: 87.0 | Costo: 6.0000
# Época 38 | W: [ 3.5705231  17.84396441] | b: 87.0 | Costo: 3.0000
# Época 39 | W: [ 3.84070684 18.00385088] | b: 87.0 | Costo: 3.0000
# Época 40 | W: [ 7.02672063 20.83691698] | b: 86.0 | Costo: 2.0000
# Época 41 | W: [ 7.83829214 14.45249848] | b: 88.0 | Costo: 5.0000
# Época 42 | W: [ 7.2961171  21.03576996] | b: 87.0 | Costo: 2.0000
# Época 43 | W: [ 8.03112472 13.52236644] | b: 87.0 | Costo: 6.0000
# Época 44 | W: [ 0.58014027 18.62944171] | b: 86.0 | Costo: 4.0000
# Época 45 | W: [ 6.3602361  16.02851642] | b: 87.0 | Costo: 4.0000
# Época 46 | W: [ 6.93119548 17.30994389] | b: 87.0 | Costo: 3.0000
# Época 47 | W: [ 7.39720185 13.79305851] | b: 87.0 | Costo: 6.0000
# Época 48 | W: [ 8.03764207 14.8634689 ] | b: 87.0 | Costo: 4.0000
# Época 49 | W: [ 4.76358959 19.10556327] | b: 86.0 | Costo: 1.0000
# Época 50 | W: [ 7.80462864 17.83489369] | b: 86.0 | Costo: 1.0000
# Época 51 | W: [ 2.67019777 18.82699729] | b: 86.0 | Costo: 3.0000
# Época 52 | W: [ 2.55718777 18.62468174] | b: 86.0 | Costo: 3.0000
# Época 53 | W: [ 6.03960261 19.63160884] | b: 85.0 | Costo: 2.0000
# Época 54 | W: [ 2.55565072 18.57259341] | b: 85.0 | Costo: 3.0000
# Época 55 | W: [ 9.6211929 19.7482435] | b: 85.0 | Costo: 1.0000
# Época 56 | W: [ 3.23042055 17.43383248] | b: 86.0 | Costo: 3.0000
# Época 57 | W: [ 3.25277318 17.74172227] | b: 86.0 | Costo: 3.0000
# Época 58 | W: [ 7.44697123 19.8642257 ] | b: 85.0 | Costo: 1.0000
# Época 59 | W: [ 8.60859538 19.975725  ] | b: 84.0 | Costo: 1.0000
# Época 60 | W: [ 6.05384102 21.0538744 ] | b: 83.0 | Costo: 5.0000
# Época 61 | W: [ 3.70254479 17.18093125] | b: 84.0 | Costo: 3.0000
# Época 62 | W: [ 7.44072915 17.46796515] | b: 84.0 | Costo: 1.0000
# Época 63 | W: [ 7.84319504 13.96579278] | b: 86.0 | Costo: 6.0000
# Época 64 | W: [ 7.85319057 18.00303207] | b: 86.0 | Costo: 1.0000
# Época 65 | W: [ 4.56362696 18.85658666] | b: 87.0 | Costo: 1.0000
# Época 66 | W: [ 5.84616159 17.50803188] | b: 87.0 | Costo: 3.0000
# Época 67 | W: [ 4.97206103 19.30743264] | b: 88.0 | Costo: 1.0000
# Época 68 | W: [ 5.72575629 21.10321415] | b: 87.0 | Costo: 3.0000
# Época 69 | W: [ 7.45213101 21.28050498] | b: 87.0 | Costo: 2.0000
# Época 70 | W: [ 8.18713863 13.76710145] | b: 87.0 | Costo: 6.0000
# Época 71 | W: [ 6.12642536 19.94152404] | b: 86.0 | Costo: 2.0000
# Época 72 | W: [ 8.17937023 14.38823264] | b: 88.0 | Costo: 5.0000
# Época 73 | W: [ 7.63719519 20.97150412] | b: 87.0 | Costo: 2.0000
# Época 74 | W: [ 4.51465245 19.26299255] | b: 88.0 | Costo: 1.0000
# Época 75 | W: [ 7.23810632 17.50893739] | b: 88.0 | Costo: 3.0000
# Época 76 | W: [ 7.70411268 13.992052  ] | b: 88.0 | Costo: 6.0000
# Época 77 | W: [ 4.43496873 19.24316438] | b: 88.0 | Costo: 1.0000
# Época 78 | W: [ 7.15842261 17.48910922] | b: 88.0 | Costo: 3.0000
# Época 79 | W: [ 7.62442897 13.97222384] | b: 88.0 | Costo: 6.0000
# Época 80 | W: [ 4.35528502 19.22333622] | b: 88.0 | Costo: 1.0000
# Época 81 | W: [ 7.07873889 17.46928106] | b: 88.0 | Costo: 3.0000
# Época 82 | W: [ 7.54474526 13.95239568] | b: 88.0 | Costo: 6.0000
# Época 83 | W: [ 5.38878184 18.89968229] | b: 86.0 | Costo: 1.0000
# Época 84 | W: [ 6.1424771 20.6954638] | b: 85.0 | Costo: 3.0000
# Época 85 | W: [ 5.93223293 20.55686253] | b: 85.0 | Costo: 3.0000
# Época 86 | W: [ 7.65860765 20.73415336] | b: 85.0 | Costo: 2.0000
# Época 87 | W: [ 4.58567592 18.88807395] | b: 85.0 | Costo: 1.0000
# Época 88 | W: [ 3.89140127 17.24303241] | b: 85.0 | Costo: 3.0000
# Época 89 | W: [ 3.98710886 18.91598522] | b: 85.0 | Costo: 1.0000
# Época 90 | W: [ 5.81387154 16.84085405] | b: 85.0 | Costo: 3.0000
# Época 91 | W: [ 5.4768734  19.33244315] | b: 86.0 | Costo: 1.0000
# Época 92 | W: [ 3.3183975  17.37048568] | b: 86.0 | Costo: 3.0000
# Época 93 | W: [ 3.34075012 17.67837547] | b: 86.0 | Costo: 3.0000
# Época 94 | W: [ 7.53494817 19.80087889] | b: 85.0 | Costo: 1.0000
# Época 95 | W: [ 3.65783943 18.88397765] | b: 85.0 | Costo: 2.0000
# Época 96 | W: [ 5.73048436 19.69386425] | b: 85.0 | Costo: 2.0000
# Época 97 | W: [ 3.98398344 19.57933816] | b: 85.0 | Costo: 3.0000
# Época 98 | W: [ 4.70160795 21.78415091] | b: 85.0 | Costo: 5.0000
# Época 99 | W: [ 3.99901113 18.49816473] | b: 86.0 | Costo: 2.0000
# Época 100 | W: [ 8.74537975 18.07463596] | b: 86.0 | Costo: 1.0000
# Época 101 | W: [ 5.59171412 19.58669895] | b: 87.0 | Costo: 1.0000
# Época 102 | W: [ 3.43323822 17.62474148] | b: 87.0 | Costo: 3.0000
# Época 103 | W: [ 3.45559084 17.93263127] | b: 87.0 | Costo: 3.0000
# Época 104 | W: [ 6.64160463 20.76569736] | b: 86.0 | Costo: 2.0000
# Época 105 | W: [ 5.97728808 19.45032722] | b: 87.0 | Costo: 1.0000
# Época 106 | W: [ 5.55449314 17.25463163] | b: 87.0 | Costo: 3.0000
# Época 107 | W: [ 1.39170945 18.40038925] | b: 88.0 | Costo: 3.0000
# Época 108 | W: [ 8.03031633 15.14770833] | b: 89.0 | Costo: 4.0000
# Época 109 | W: [ 8.84639818 15.06723241] | b: 89.0 | Costo: 4.0000
# Época 110 | W: [ 5.5723457  19.30932677] | b: 88.0 | Costo: 1.0000
# Época 111 | W: [ 6.32604096 21.10510828] | b: 87.0 | Costo: 3.0000
# Época 112 | W: [ 6.11579679 20.96650701] | b: 87.0 | Costo: 3.0000
# Época 113 | W: [ 7.8421715  21.14379784] | b: 87.0 | Costo: 2.0000
# Época 114 | W: [ 8.57717913 13.63039432] | b: 87.0 | Costo: 6.0000
# Época 115 | W: [ 5.4661571 18.6431002] | b: 85.0 | Costo: 1.0000
# Época 116 | W: [ 6.21985236 20.43888171] | b: 84.0 | Costo: 2.0000
# Época 117 | W: [ 5.55553581 19.12351157] | b: 85.0 | Costo: 1.0000
# Época 118 | W: [ 3.39705991 17.1615541 ] | b: 85.0 | Costo: 3.0000
# Época 119 | W: [ 3.41941254 17.46944389] | b: 85.0 | Costo: 3.0000
# Época 120 | W: [ 7.1575969  17.75647779] | b: 85.0 | Costo: 1.0000
# Época 121 | W: [ 3.62852502 17.68776509] | b: 86.0 | Costo: 3.0000
# Época 122 | W: [ 7.36670938 17.97479899] | b: 86.0 | Costo: 1.0000
# Época 123 | W: [ 7.69261139 13.3436416 ] | b: 86.0 | Costo: 5.0000
# Época 124 | W: [ 5.25553816 19.07853129] | b: 85.0 | Costo: 1.0000
# Época 125 | W: [ 3.35163358 17.30774141] | b: 85.0 | Costo: 3.0000
# Época 126 | W: [ 6.94619334 17.85585443] | b: 85.0 | Costo: 1.0000
# Época 127 | W: [ 3.49836695 17.79615849] | b: 86.0 | Costo: 3.0000
# Época 128 | W: [ 6.68438074 20.62922459] | b: 85.0 | Costo: 2.0000
# Época 129 | W: [ 3.56441447 17.67826575] | b: 86.0 | Costo: 3.0000
# Época 130 | W: [ 7.30259883 17.96529966] | b: 86.0 | Costo: 1.0000
# Época 131 | W: [ 8.11980337 14.90890217] | b: 87.0 | Costo: 4.0000
# Época 132 | W: [ 4.86891047 18.90263297] | b: 87.0 | Costo: 1.0000
# Época 133 | W: [ 7.55922461 21.01430659] | b: 86.0 | Costo: 2.0000
# Época 134 | W: [ 8.29423224 13.50090306] | b: 86.0 | Costo: 6.0000
# Época 135 | W: [ 7.97961385 14.63673273] | b: 86.0 | Costo: 4.0000
# Época 136 | W: [ 4.70556137 18.87882709] | b: 85.0 | Costo: 1.0000
# Época 137 | W: [ 4.01128672 17.23378555] | b: 85.0 | Costo: 3.0000
# Época 138 | W: [ 4.4703316  18.73469254] | b: 85.0 | Costo: 1.0000
# Época 139 | W: [ 4.39388953 21.22596744] | b: 84.0 | Costo: 5.0000
# Época 140 | W: [ 6.61929229 18.41449801] | b: 85.0 | Costo: 1.0000
# Época 141 | W: [-0.1898478 18.5103182] | b: 85.0 | Costo: 4.0000
# Época 142 | W: [ 5.67919288 19.22263304] | b: 86.0 | Costo: 1.0000
# Época 143 | W: [ 3.77528831 17.45184317] | b: 86.0 | Costo: 3.0000
# Época 144 | W: [ 5.44396312 19.07849849] | b: 86.0 | Costo: 1.0000
# Época 145 | W: [ 5.69251344 19.79370399] | b: 85.0 | Costo: 2.0000
# Época 146 | W: [ 5.62698668 18.48754753] | b: 84.0 | Costo: 1.0000
# Época 147 | W: [ 5.54907562 18.12322309] | b: 84.0 | Costo: 1.0000
# Época 148 | W: [-0.3684173  17.35315999] | b: 85.0 | Costo: 5.0000
# Época 149 | W: [ 5.74381181 19.52380378] | b: 84.0 | Costo: 2.0000
# Época 150 | W: [ 3.29364984 17.99175125] | b: 84.0 | Costo: 2.0000
# Época 151 | W: [ 8.04001846 17.56822248] | b: 84.0 | Costo: 1.0000
# Época 152 | W: [ 4.67768426 18.80770846] | b: 85.0 | Costo: 1.0000
# Época 153 | W: [ 4.60124219 21.29898336] | b: 84.0 | Costo: 5.0000
# Época 154 | W: [ 6.73337201 17.61236554] | b: 86.0 | Costo: 2.0000
# Época 155 | W: [ 5.51632525 19.44032064] | b: 87.0 | Costo: 1.0000
# Época 156 | W: [ 3.61242068 17.66953077] | b: 87.0 | Costo: 3.0000
# Época 157 | W: [ 7.68822832 19.94998973] | b: 86.0 | Costo: 1.0000
# Época 158 | W: [ 7.50279208 19.81923437] | b: 85.0 | Costo: 1.0000
# Época 159 | W: [ 3.62568334 18.90233312] | b: 85.0 | Costo: 2.0000
# Época 160 | W: [ 5.69832827 19.71221972] | b: 85.0 | Costo: 2.0000
# Época 161 | W: [ 6.99765073 17.42894991] | b: 85.0 | Costo: 2.0000
# Época 162 | W: [ 5.78060398 19.25690501] | b: 86.0 | Costo: 1.0000
# Época 163 | W: [ 3.8766994  17.48611513] | b: 86.0 | Costo: 3.0000
# Época 164 | W: [ 3.97240698 19.15906795] | b: 86.0 | Costo: 2.0000
# Época 165 | W: [ 6.04505191 19.96895455] | b: 86.0 | Costo: 2.0000
# Época 166 | W: [ 8.09799679 14.41566315] | b: 88.0 | Costo: 5.0000
# Época 167 | W: [ 7.55582174 20.99893463] | b: 87.0 | Costo: 2.0000
# Época 168 | W: [ 8.36739325 14.61451613] | b: 89.0 | Costo: 5.0000
# Época 169 | W: [ 0.26238285 19.49782629] | b: 89.0 | Costo: 4.0000
# Época 170 | W: [ 1.43056073 19.38900359] | b: 89.0 | Costo: 3.0000
# Época 171 | W: [ 7.07446454 20.45976045] | b: 88.0 | Costo: 1.0000
# Época 172 | W: [ 8.2360887  20.57125975] | b: 87.0 | Costo: 2.0000
# Época 173 | W: [ 2.93719822 17.82746387] | b: 88.0 | Costo: 3.0000
# Época 174 | W: [ 6.63694483 19.00974172] | b: 88.0 | Costo: 1.0000
# Época 175 | W: [-0.17219526 19.10556191] | b: 88.0 | Costo: 4.0000
# Época 176 | W: [ 9.73535054 17.75446187] | b: 88.0 | Costo: 3.0000
# Época 177 | W: [ 1.19757011 19.19102494] | b: 89.0 | Costo: 3.0000
# Época 178 | W: [ 6.9734249  14.30108068] | b: 89.0 | Costo: 5.0000
# Época 179 | W: [ 5.8698481  18.31174236] | b: 88.0 | Costo: 2.0000
# Época 180 | W: [-0.44359234 19.12895502] | b: 88.0 | Costo: 4.0000
# Época 181 | W: [ 9.46395345 17.77785499] | b: 88.0 | Costo: 3.0000
# Época 182 | W: [ 6.93570817 18.10710471] | b: 89.0 | Costo: 3.0000
# Época 183 | W: [ 5.55960387 19.52491496] | b: 89.0 | Costo: 1.0000
# Época 184 | W: [ 6.31329913 21.32069648] | b: 88.0 | Costo: 3.0000
# Época 185 | W: [ 6.10305496 21.1820952 ] | b: 88.0 | Costo: 3.0000
# Época 186 | W: [ 7.82942968 21.35938603] | b: 88.0 | Costo: 2.0000
# Época 187 | W: [ 8.5644373  13.84598251] | b: 88.0 | Costo: 6.0000
# Época 188 | W: [ 5.45341527 18.85868839] | b: 86.0 | Costo: 1.0000
# Época 189 | W: [ 6.20711053 20.6544699 ] | b: 85.0 | Costo: 3.0000
# Época 190 | W: [ 5.99686636 20.51586863] | b: 85.0 | Costo: 3.0000
# Época 191 | W: [ 7.72324107 20.69315946] | b: 85.0 | Costo: 2.0000
# Época 192 | W: [ 8.53481258 14.30874096] | b: 87.0 | Costo: 6.0000
# Época 193 | W: [ 0.17859378 17.45958607] | b: 87.0 | Costo: 5.0000
# Época 194 | W: [ 6.11517728 17.44072124] | b: 87.0 | Costo: 3.0000
# Época 195 | W: [ 6.44923268 19.88453698] | b: 86.0 | Costo: 1.0000
# Época 196 | W: [ 2.96528079 18.82552155] | b: 86.0 | Costo: 3.0000
# Época 197 | W: [ 7.08661592 19.96585777] | b: 85.0 | Costo: 2.0000
# Época 198 | W: [ 8.24824007 20.07735707] | b: 84.0 | Costo: 2.0000
# Época 199 | W: [ 2.98386404 18.72918418] | b: 85.0 | Costo: 3.0000
# Época 200 | W: [ 0.6212964 18.4063042] | b: 85.0 | Costo: 4.0000
# Época 201 | W: [ 6.26520022 19.47706106] | b: 84.0 | Costo: 2.0000
# Época 202 | W: [ 8.31814509 13.92376966] | b: 86.0 | Costo: 6.0000
# Época 203 | W: [ 0.21313469 18.80707982] | b: 86.0 | Costo: 4.0000
# Época 204 | W: [ 0.54656103 18.77496814] | b: 86.0 | Costo: 4.0000
# Época 205 | W: [ 3.59850816 18.37813546] | b: 86.0 | Costo: 2.0000
# Época 206 | W: [ 8.34487679 17.95460669] | b: 86.0 | Costo: 1.0000
# Época 207 | W: [ 5.0321536  19.05652484] | b: 86.0 | Costo: 1.0000
# Época 208 | W: [ 5.81898859 16.98657757] | b: 86.0 | Costo: 3.0000
# Época 209 | W: [ 7.19474479 14.57655613] | b: 86.0 | Costo: 5.0000
# Época 210 | W: [ 8.64353327 18.32341848] | b: 85.0 | Costo: 1.0000
# Época 211 | W: [ 5.61827747 18.90707573] | b: 85.0 | Costo: 1.0000
# Época 212 | W: [ 5.86682779 19.62228123] | b: 84.0 | Costo: 2.0000
# Época 213 | W: [ 3.00382322 19.17197432] | b: 85.0 | Costo: 3.0000
# Época 214 | W: [ 7.00355235 18.10575673] | b: 86.0 | Costo: 1.0000
# Época 215 | W: [ 3.15599342 17.77425661] | b: 86.0 | Costo: 3.0000
# Época 216 | W: [ 3.65851896 19.11061415] | b: 86.0 | Costo: 2.0000
# Época 217 | W: [ 5.7311639  19.92050075] | b: 86.0 | Costo: 2.0000
# Época 218 | W: [ 7.03048636 17.63723094] | b: 86.0 | Costo: 2.0000
# Época 219 | W: [ 5.81343961 19.46518603] | b: 87.0 | Costo: 1.0000
# Época 220 | W: [ 3.90953503 17.69439616] | b: 87.0 | Costo: 3.0000
# Época 221 | W: [ 5.57820985 19.32105148] | b: 87.0 | Costo: 1.0000
# Época 222 | W: [ 5.82676016 20.03625699] | b: 86.0 | Costo: 2.0000
# Época 223 | W: [ 5.7612334  18.73010052] | b: 85.0 | Costo: 1.0000
# Época 224 | W: [ 5.66570945 19.34197227] | b: 86.0 | Costo: 1.0000
# Época 225 | W: [ 3.50723355 17.3800148 ] | b: 86.0 | Costo: 3.0000
# Época 226 | W: [ 3.52958617 17.68790459] | b: 86.0 | Costo: 3.0000
# Época 227 | W: [ 7.26777053 17.9749385 ] | b: 86.0 | Costo: 1.0000
# Época 228 | W: [ 7.59367255 13.3437811 ] | b: 86.0 | Costo: 5.0000
# Época 229 | W: [ 5.17975889 18.83030723] | b: 86.0 | Costo: 1.0000
# Época 230 | W: [ 5.93345416 20.62608874] | b: 85.0 | Costo: 3.0000
# Época 231 | W: [ 6.27538056 17.94145528] | b: 86.0 | Costo: 1.0000
# Época 232 | W: [ 2.33942033 20.35173211] | b: 86.0 | Costo: 3.0000
# Época 233 | W: [ 2.57093774 18.71478972] | b: 86.0 | Costo: 3.0000
# Época 234 | W: [ 6.92524781 13.31037768] | b: 86.0 | Costo: 5.0000
# Época 235 | W: [ 5.44323319 18.9798481 ] | b: 85.0 | Costo: 1.0000
# Época 236 | W: [ 3.53932861 17.20905823] | b: 85.0 | Costo: 3.0000
# Época 237 | W: [ 3.56168123 17.51694802] | b: 85.0 | Costo: 3.0000
# Época 238 | W: [ 7.29986559 17.80398193] | b: 85.0 | Costo: 1.0000
# Época 239 | W: [ 7.76981571 13.55283569] | b: 86.0 | Costo: 6.0000
# Época 240 | W: [ 5.70910243 19.72725828] | b: 85.0 | Costo: 2.0000
# Época 241 | W: [ 7.0084249  17.44398847] | b: 85.0 | Costo: 2.0000
# Época 242 | W: [ 5.79137815 19.27194356] | b: 86.0 | Costo: 1.0000
# Época 243 | W: [ 3.88747357 17.50115369] | b: 86.0 | Costo: 3.0000
# Época 244 | W: [ 3.98318115 19.1741065 ] | b: 86.0 | Costo: 2.0000
# Época 245 | W: [ 6.05582608 19.9839931 ] | b: 86.0 | Costo: 2.0000
# Época 246 | W: [ 8.10877095 14.4307017 ] | b: 88.0 | Costo: 5.0000
# Época 247 | W: [ 7.56659591 21.01397319] | b: 87.0 | Costo: 2.0000
# Época 248 | W: [ 8.37816742 14.62955469] | b: 89.0 | Costo: 5.0000
# Época 249 | W: [ 0.27315702 19.51286485] | b: 89.0 | Costo: 4.0000
# Época 250 | W: [ 0.0424362  17.94361579] | b: 89.0 | Costo: 5.0000
# Época 251 | W: [ 5.9790197  17.92475097] | b: 89.0 | Costo: 3.0000
# Época 252 | W: [ 0.68464763 19.26954452] | b: 89.0 | Costo: 4.0000
# Época 253 | W: [ 7.49161251 15.8776474 ] | b: 90.0 | Costo: 4.0000
# Época 254 | W: [ 7.0931752  17.47341611] | b: 90.0 | Costo: 3.0000
# Época 255 | W: [ 5.41695757 18.60610035] | b: 90.0 | Costo: 3.0000
# Época 256 | W: [ 0.85737511 18.82248496] | b: 90.0 | Costo: 3.0000
# Época 257 | W: [ 5.44629774 19.78293268] | b: 90.0 | Costo: 1.0000
# Época 258 | W: [ 6.199993   21.57871419] | b: 89.0 | Costo: 3.0000
# Época 259 | W: [ 5.98974883 21.44011292] | b: 89.0 | Costo: 3.0000
# Época 260 | W: [ 7.71612355 21.61740375] | b: 89.0 | Costo: 2.0000
# Época 261 | W: [ 8.45113117 14.10400023] | b: 89.0 | Costo: 6.0000
# Época 262 | W: [ 8.13651278 15.23982989] | b: 89.0 | Costo: 4.0000
# Época 263 | W: [ 9.98291751 15.8034075 ] | b: 89.0 | Costo: 4.0000
# Época 264 | W: [ 7.57593402 21.34523431] | b: 88.0 | Costo: 2.0000
# Época 265 | W: [ 8.31094165 13.83183079] | b: 88.0 | Costo: 6.0000
# Época 266 | W: [ 7.99632326 14.96766045] | b: 88.0 | Costo: 4.0000
# Época 267 | W: [ 4.46355221 19.11731657] | b: 88.0 | Costo: 1.0000
# Época 268 | W: [ 7.15386635 21.22899019] | b: 87.0 | Costo: 2.0000
# Época 269 | W: [ 7.88887398 13.71558666] | b: 87.0 | Costo: 6.0000
# Época 270 | W: [ 5.82816071 19.89000925] | b: 86.0 | Costo: 2.0000
# Época 271 | W: [ 7.12748317 17.60673944] | b: 86.0 | Costo: 2.0000
# Época 272 | W: [ 5.91043642 19.43469453] | b: 87.0 | Costo: 1.0000
# Época 273 | W: [ 5.48764147 17.23899894] | b: 87.0 | Costo: 3.0000
# Época 274 | W: [ 1.32485779 18.38475656] | b: 88.0 | Costo: 3.0000
# Época 275 | W: [ 7.96346466 15.13207564] | b: 89.0 | Costo: 5.0000
# Época 276 | W: [ 5.48467074 21.39945502] | b: 88.0 | Costo: 3.0000
# Época 277 | W: [ 7.24418518 17.71101707] | b: 89.0 | Costo: 3.0000
# Época 278 | W: [ 7.71019154 14.19413169] | b: 89.0 | Costo: 6.0000
# Época 279 | W: [ 4.4410476  19.44524407] | b: 89.0 | Costo: 1.0000
# Época 280 | W: [ 7.13136174 21.55691769] | b: 88.0 | Costo: 2.0000
# Época 281 | W: [ 7.86636937 14.04351416] | b: 88.0 | Costo: 6.0000
# Época 282 | W: [ 5.80565609 20.21793675] | b: 87.0 | Costo: 2.0000
# Época 283 | W: [ 5.74012933 18.91178028] | b: 86.0 | Costo: 1.0000
# Época 284 | W: [ 4.83188719 18.55193398] | b: 86.0 | Costo: 1.0000
# Época 285 | W: [ 6.11442182 17.20337919] | b: 86.0 | Costo: 3.0000
# Época 286 | W: [ 6.44847722 19.64719493] | b: 85.0 | Costo: 1.0000
# Época 287 | W: [ 2.96452533 18.5881795 ] | b: 85.0 | Costo: 3.0000
# Época 288 | W: [ 7.08586046 19.72851572] | b: 84.0 | Costo: 2.0000
# Época 289 | W: [ 6.8512285  17.42569557] | b: 84.0 | Costo: 1.0000
# Época 290 | W: [ 5.77780634 18.99257156] | b: 85.0 | Costo: 1.0000
# Época 291 | W: [ 3.87390176 17.22178168] | b: 85.0 | Costo: 3.0000
# Época 292 | W: [ 5.54257658 18.848437  ] | b: 85.0 | Costo: 1.0000
# Época 293 | W: [ 5.46613451 21.3397119 ] | b: 84.0 | Costo: 5.0000
# Época 294 | W: [ 3.63886379 17.96745413] | b: 87.0 | Costo: 3.0000
# Época 295 | W: [ 6.82487758 20.80052023] | b: 86.0 | Costo: 2.0000
# Época 296 | W: [ 8.05118773 14.86187661] | b: 87.0 | Costo: 4.0000
# Época 297 | W: [ 4.77713525 19.10397097] | b: 86.0 | Costo: 1.0000
# Época 298 | W: [ 7.8181743 17.8333014] | b: 86.0 | Costo: 1.0000
# Época 299 | W: [ 2.68374343 18.825405  ] | b: 86.0 | Costo: 3.0000
# Época 300 | W: [ 2.57073343 18.62308944] | b: 86.0 | Costo: 3.0000

# %% [markdown]
# 3. GRAFIQUE LOS COSTOS VS LAS EPOCHS

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs + 1), costos, color='orange', linewidth=2)
plt.title("Evolución del costo durante el entrenamiento", fontsize=14)
plt.xlabel("Época", fontsize=12)
plt.ylabel("Costo (proporción de errores)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. GRAFIQUE EL ACCURACY VS LAS EPOCHS

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, epochs + 1), accuracies, color='blue', linewidth=2)
plt.title("Evolución del accuracy durante el entrenamiento", fontsize=14)
plt.xlabel("Época", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.ylim(min(accuracies) - 0.01, max(accuracies) + 0.01)  # escala dinámica
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 5. PRESENTE LAS METRICAS DE CLASIFICACION CON SU RESPECTIVA INTERPRETACION (ACCURACY, F1-SCORE, MATRIZ DE CONFUSION, SENSIBILIDAD Y ESPECIFICIDAD).

# %%
# Calcular métricas
accuracy = accuracy_score(y, y_pred)
f1 = f1_score(y, y_pred)
cm = confusion_matrix(y, y_pred)

tn, fp, fn, tp = cm.ravel()
sensibilidad = tp / (tp + fn)
especificidad = tn / (tn + fp)

# Mostrar resultados
print("MÉTRICAS DE CLASIFICACIÓN")
print(f"Accuracy      : {accuracy:.4f}")
print(f"F1-Score      : {f1:.4f}")
print(f"Sensibilidad  : {sensibilidad:.4f}")
print(f"Especificidad : {especificidad:.4f}")
print("\nMatriz de Confusión:")
print(cm)
# Out:
# MÉTRICAS DE CLASIFICACIÓN
# Accuracy      : 0.9800
# F1-Score      : 0.9799
# Sensibilidad  : 0.9733
# Especificidad : 0.9867
#
# Matriz de Confusión:
# [[74  1]
#  [ 2 73]]

# %% [markdown]
# 6. SIMULE UNA MUESTRA NUEVA (COMO SI FUESE UN PACIENTE NUEVO) Y HAGA LA CLASIFICACION DE ES PACIENTE CON EL ALGORITMO ENTRENADO

# %%
paciente_nuevo = np.array([[2.5, -6.3 ]])   

# Clasificación con el modelo entrenado
prediccion = perceptron.predict(paciente_nuevo)

print("Paciente:", paciente_nuevo)
print("Clase:", prediccion[0])
# Out:
# Paciente: [[ 2.5 -6.3]]
# Clase: 0
